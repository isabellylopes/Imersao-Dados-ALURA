# %% [markdown]
# Analista: Isabelly Cristine Lopes
#
# Linkedin: https://www.linkedin.com/in/isabelly-lopes-8a9b59204/
#
# Github: http://github.com/isabellylopes

# %% [markdown]
# # Análise dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Lendo os dados.
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

#Como os dados estão em arquivo 'zip' precisamos usar o método 'compression' para fazer a conversão para 'csv.'
dados = pd.read_csv(url_dados, compression='zip')

#Mostrando as 5 primeiras linhas do arquivo.
dados.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# ## Análise exploratória

# %% [markdown]
# * Analisando os valores únicos das quatro colunas: 'tratamento', 'tempo', 'dose' e 'droga'.

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48], dtype=int64)

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# * Fazendo a contagem dos valores únicos dessas mesmas colunas.

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tempo'].value_counts()
# Out:
# 48    8250
# 72    7792
# 24    7772
# Name: tempo, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# b046f598b       1
# 82dcdb180       1
# 14886a5b2       1
# 7a2ea4684       1
# 07cca32e8       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# # Desafio 01
# ##  Investigar por que a classe 'tratamento' é tão desbalanceada?
#
# * Verificando a propoção entre os valores

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# * Aqui percebemos que:
#
#
#  Os tratamentos **com drogas** expressam a maior parte dos dados. Com **92%** dos dados coletados e o tratamento sem drogas, ou seja, **com controle** representa apenas **0.8%** dos dados.

# %%
dados[dados['tratamento']=='com_controle']
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 25     id_0054388ec  com_controle     48   D1  cacb2b860 -0.6696 -0.2718
# 38     id_0079af0fb  com_controle     24   D1  cacb2b860 -0.1636 -1.8230
# 40     id_007bfbb91  com_controle     24   D2  cacb2b860 -1.3200 -1.7340
# 47     id_008a986b7  com_controle     48   D2  cacb2b860  0.4860  0.1430
# 63     id_009d8340f  com_controle     24   D2  cacb2b860  0.4471 -0.0839
# ...             ...           ...    ...  ...        ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  cacb2b860  0.0465  0.6430
# 23747  id_ff469c482  com_controle     72   D1  cacb2b860 -0.6204 -1.3800
# 23768  id_ff89331ca  com_controle     72   D2  cacb2b860 -0.1051  0.4335
# 23793  id_ffd26f361  com_controle     48   D2  cacb2b860  0.6008  0.2781
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
dados[(dados['tratamento']=='com_droga') & dados['droga']=='cacb2b860']
# Out:
# Empty DataFrame
# Columns: [id, tratamento, tempo, dose, droga, g-0, g-1, g-2, g-3, g-4, g-5, g-6, g-7, g-8, g-9, g-10, g-11, g-12, g-13, g-14, g-15, g-16, g-17, g-18, g-19, g-20, g-21, g-22, g-23, g-24, g-25, g-26, g-27, g-28, g-29, g-30, g-31, g-32, g-33, g-34, g-35, g-36, g-37, g-38, g-39, g-40, g-41, g-42, g-43, g-44, g-45, g-46, g-47, g-48, g-49, g-50, g-51, g-52, g-53, g-54, g-55, g-56, g-57, g-58, g-59, g-60, g-61, g-62, g-63, g-64, g-65, g-66, g-67, g-68, g-69, g-70, g-71, g-72, g-73, g-74, g-75, g-76, g-77, g-78, g-79, g-80, g-81, g-82, g-83, g-84, g-85, g-86, g-87, g-88, g-89, g-90, g-91, g-92, g-93, g-94, ...]
# Index: []
#
# [0 rows x 877 columns]

# %% [markdown]
# * A droga mais utilizada nesse experimento é a *'cacb2b860'* com o total de **1866** entradas.E ela só é encontrada nas linhas de tratamento: **com_controle**, logo, posso perceber que todas as outras drogas inseridas nesse experimento são drogas, digamos, aleatórias e o intuito dessa pesquisa era saber o impacto da droga *'cacb2b860'*.

# %% [markdown]
# # Desafio 02:
#
# ## Plotar as últimas linhas.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %% [markdown]
# # Desafio 03:
#
# ## Proporção das classes de tratamento.

# %%
#Criando a representação área do gráfico.
fig1, ax1 = plt.subplots()
ax1.pie(dados['tratamento'].value_counts(normalize=True),labels=['Com droga', 'Com controle'], autopct='%1.1f%%')
plt.title('Tratamento')
# Out:
# Text(0.5, 1.0, 'Tratamento')

# %% [markdown]
# # Desafio 04:
#
# ## Quantos tipos de drogas foram investigadas?

# %%
dados['droga'].nunique()
# Out:
# 3289

# %% [markdown]
# # Desafio 05:
#
# ## Renomear as colunas retirando o hífem o método query.

# %%
nome_coluna = dados.columns
nome_novo = []

for nome in nome_coluna:
    nome_novo.append(nome.replace('-',''))
        
dados.columns = nome_novo
dados.head()
# Out:
#              id tratamento  tempo dose      droga      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...
